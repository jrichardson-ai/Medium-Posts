# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import numpy as np
import re
from urllib.parse import urlparse
import pyarrow

import os
from pathlib import Path
os.environ['USER_AGENT'] = 'myagent'

#os.chdir("/YOUR PATH HERE")
os.chdir("/Users/roamingt/Documents/Medium Posts")
cwd = Path.cwd()
notebook_path = os.getcwd()

# %%
"""
List of publications:

https://www.consumerfinance.gov/compliance/supervisory-highlights/
"""
# ---- SCRAPE THE CFPB Supervisory Highlights DATA ----
# Classify the CFPB links that are scraped into categories to easily manipulate them
# PDF is for links that can be hit directly
# RELATIVE_PDF is for links that need the site added
# LANDING_PAGE is for the one useful link to the most recent file page that contains the actual link
# IGNORE and UNKNOWN are what they say on the tin

def classify_link(link):
    if not link:
        return 'IGNORE'
    
    # 1. Skip "View More" or anything matching those patterns
    elif 'activity-log' in link or 'view-more' in link:
        return 'IGNORE'
    
    # 2. Direct PDF from 'files.consumerfinance.gov'
    elif link.startswith('https://files.consumerfinance.gov/') and link.endswith('.pdf'):
        return 'PDF'
    
    # 3. Relative PDF link, needs prefix
    elif link.startswith('/documents/') and link.endswith('.pdf'):
        return 'RELATIVE_PDF'
    
    # 4. Landing pages (not a PDF, might require scraping)
    elif link.startswith('/data-research/research-reports/') :
        return 'LANDING_PAGE'

    # 5. Unknown/Other (optional)
    else:
        return 'UNKNOWN'

# For PDFs, we can use links as is. For RELATIVE_PDF & LANDING_PAGE we need to add the subdomain
def normalize_link(link, link_type):
    if link_type == 'PDF':
        return link
    
    elif link_type in ['RELATIVE_PDF', 'LANDING_PAGE']:
        return f"https://www.consumerfinance.gov{link}"
    
    else:
        return None


# For PDF links, we want the actual file name
def extract_filename_from_link(url):
    """Extracts the filename from a URL."""
    parsed_url = urlparse(url)
    filename = os.path.basename(parsed_url.path)
    
    # Safety: fallback if something goes wrong
    if not filename:
        filename = 'downloaded_report.pdf'
    return filename


# This does the actual downloading of the PDFs
def download_pdf(file_url, save_path):
    """Download a PDF from the given URL to a local path."""
    try:
        response = requests.get(file_url, timeout=15)

        if response.status_code == 200:
            with open(save_path, 'wb') as f:
                f.write(response.content)
            print(f"[DOWNLOADED] {save_path}")
            return True
        else:
            print(f"[FAILED] Download failed: {file_url} | Status: {response.status_code}")
            return False

    except requests.RequestException as e:
        print(f"[ERROR] Exception occurred for {file_url}: {e}")
        return False

# Currently we only have one landing page link, so we could hard code this, but other regulatory bodies might have similar headaches
def get_pdf_link_from_report_page(report_page_url):
    """Scrape the report page to find any direct PDF link."""
    print(f"Scraping PDF link from: {report_page_url}")

    response = requests.get(report_page_url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all <a> tags with class 'a-link' and href
    pdf_links = soup.find_all('a', class_='a-link', href=True)

    for link_tag in pdf_links:
        href = link_tag['href']
        
        # Check if it's a direct PDF link
        if href.lower().endswith('.pdf'):
            # Full URL if relative
            if href.startswith('/'):
                href = 'https://www.consumerfinance.gov' + href

            print(f"Found PDF link: {href}")
            return href

# We're checking if a file to be downloaded already exists locally in our target folder
#      If it does NOT exist, we download and return the save path
#      If it DOES exist, we return the save path of the existing file
def process_download(normalized_link, download_folder):
    """Download a file using its filename from the URL."""
    
    # Step 1: Direct PDF link
    if normalized_link.lower().endswith('.pdf'):
        filename = extract_filename_from_link(normalized_link)
        save_path = os.path.join(download_folder, filename)

        # Check if file exists locally
        if os.path.isfile(save_path):
            print(f"[SKIP] File already exists locally: {save_path}")
            return save_path

        success = download_pdf(normalized_link, save_path)
        local_filename = download_folder + "/" + filename
        return save_path if success else None

    # Step 2: Landing page → scrape for PDF link
    pdf_link = get_pdf_link_from_report_page(normalized_link)

    if pdf_link:
        filename = extract_filename_from_link(pdf_link)
        save_path = os.path.join(download_folder, filename)

        # Check if file exists locally
        if os.path.isfile(save_path):
            print(f"[SKIP] File already exists locally (scraped): {save_path}")
            return save_path

        else:
            success = download_pdf(pdf_link, save_path)
            local_filename = download_folder + "/" + filename
            return local_filename if success else None
        print(f"[FAILED] No PDF found or downloaded for: {normalized_link}")

# Get the most recent mod date of a file
def get_file_modification_date(file_path):
    """Return file modification date as YYYYMMDD string."""
    try:
        # Get modification time as Unix timestamp
        mod_timestamp = os.path.getmtime(file_path)
        
        # Convert to datetime
        mod_datetime = datetime.fromtimestamp(mod_timestamp)
        
        # Format as YYYYMMDD
        mod_date_str = mod_datetime.strftime('%Y%m%d')
        
        return mod_date_str
    
    except Exception as e:
        print(f"[ERROR] Could not read mod date for {file_path}: {e}")
        return None

# %%
# Local folder to store downloaded PDFs (optional)
local_download_folder = 'scraped data files'
os.makedirs(local_download_folder, exist_ok=True)

url = "https://www.consumerfinance.gov/compliance/supervisory-highlights/"
response = requests.get(url)
# raises exception for errors, instead handled manually response.raise_for_status()
soup = BeautifulSoup(response.text, 'html.parser')

#Read the given url containing the links. from inspection, we know this is the class we want
link_elements = soup.select('a.a-link.a-link--jump')

data = []


for link in link_elements:
    title_element = link.select_one('span.a-link__text')

    if not title_element:
        continue  # Skip anything without a proper title
    
    #get the link
    title = title_element.get_text(strip=True)
    href = link['href']

    # Classify the link type
    link_type = classify_link(href)

    # SKIP garbage links immediately
    if link_type == 'IGNORE':
        print(f"[SKIP] Ignored link: {href}")
        continue

    # Normalize link (if necessary)
    normalized_link = normalize_link(href, link_type)
    print(link_type, normalized_link)

    if normalized_link:
        downloaded_filename = process_download(normalized_link, local_download_folder)
    else:
        downloaded_filename = None
    
    # Get today's date in YYYYMMDD format
    file_loc = ''
    scrape_date = ''
    if downloaded_filename:
        file_loc = downloaded_filename
        scrape_date = datetime.today().strftime('%Y%m%d')
        #print(scrape_date)
    elif normalized_link:
        print(f"[WARN] No file downloaded for link: {normalized_link}")
    
    # Extract year and season from the title
    year_match = re.search(r'\b(20\d{2})\b', title)
    year = year_match.group(1) if year_match else 'Unknown'

    season_match = re.search(r'(Winter|Spring|Summer|Fall)', title, re.IGNORECASE)
    season = season_match.group(1).capitalize() if season_match else 'Unknown'
    clean_filename = title.replace('Download ', '')

    # Append the cleaned data row
    data.append({
        'Title': clean_filename,
        'Link': href,
        'Link Type': link_type,
        'Normalized Link': normalized_link,
        'Year': year,
        'Season': season,
        'Agency': 'CFPB',
        'File Location': file_loc,         # Will fill this later in download/upload
        'Drive Link': '',              # Will fill this later in upload
        'Summarized?': False,          # Will update post-summarization
        'Summary': '',
        'Scraped Date': scrape_date
    })

# Convert to DataFrame (single pass complete)
df = pd.DataFrame(data)

print(f"[INFO] Scraped {len(df)} records")
#print(df)
# Out:
# LANDING_PAGE https://www.consumerfinance.gov/data-research/research-reports/supervisory-highlights-advanced-technologies-special-edition-issue-38-winter-2025/
# Scraping PDF link from: https://www.consumerfinance.gov/data-research/research-reports/supervisory-highlights-advanced-technologies-special-edition-issue-38-winter-2025/
# Found PDF link: https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights-advanced-technologies_2025-01.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights-advanced-technologies_2025-01.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights-special-ed-student-lending-issue-36-winter_2024-12.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights-special-ed-student-lending-issue-36-winter_2024-12.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_Supervisory-Highlights-Issue-37_Winter-2024.pdf
# [DOWNLOADED] scraped data files/cfpb_Supervisory-Highlights-Issue-37_Winter-2024.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights-special-ed-auto-finance_2024-10.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights-special-ed-auto-finance_2024-10.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-34_2024-07.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-34_2024-07.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-32_2024-04.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-32_2024-04.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-33_2024-04.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-33_2024-04.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory_highlights_junk_fees-update-special-ed_2023-09.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory_highlights_junk_fees-update-special-ed_2023-09.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-30_2023-07.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-30_2023-07.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights-junk-fees-special-edition_2023-03.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights-junk-fees-special-edition_2023-03.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-28_2022-11.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-28_2022-11.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_student-loan-servicing-supervisory-highlights-special-edition_report_2022-09.pdf
# [DOWNLOADED] scraped data files/cfpb_student-loan-servicing-supervisory-highlights-special-edition_report_2022-09.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-26_2022-04.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-26_2022-04.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-25_2021-12.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-25_2021-12.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-24_2021-06.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-24_2021-06.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-23_2021-01.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-23_2021-01.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-21_2020-02.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-21_2020-02.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-22_2020-09.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-22_2020-09.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-20_122019.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-20_122019.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-19_092019.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-19_092019.pdf
# PDF https://files.consumerfinance.gov/f/documents/cfpb_supervisory-highlights_issue-18_032019.pdf
# [DOWNLOADED] scraped data files/cfpb_supervisory-highlights_issue-18_032019.pdf
# RELATIVE_PDF https://www.consumerfinance.gov/documents/6817/bcfp_supervisory-highlights_issue-17_2018-09.pdf
# [DOWNLOADED] scraped data files/bcfp_supervisory-highlights_issue-17_2018-09.pdf
# RELATIVE_PDF https://www.consumerfinance.gov/documents/5386/201709_cfpb_Supervisory-Highlights_Issue-16.pdf
# [DOWNLOADED] scraped data files/201709_cfpb_Supervisory-Highlights_Issue-16.pdf
# RELATIVE_PDF https://www.consumerfinance.gov/documents/4608/201704_cfpb_Supervisory-Highlights_Issue-15.pdf
# [DOWNLOADED] scraped data files/201704_cfpb_Supervisory-Highlights_Issue-15.pdf
# RELATIVE_PDF https://www.consumerfinance.gov/documents/2774/201703_cfpb_Supervisory-Highlights-Consumer-Reporting-Special-Edition.pdf
# [DOWNLOADED] scraped data files/201703_cfpb_Supervisory-Highlights-Consumer-Reporting-Special-Edition.pdf
# PDF https://files.consumerfinance.gov/f/documents/Supervisory_Highlights_Issue_13__Final_10.31.16.pdf
# [DOWNLOADED] scraped data files/Supervisory_Highlights_Issue_13__Final_10.31.16.pdf
# PDF https://files.consumerfinance.gov/f/documents/Supervisory_Highlights_Issue_12.pdf
# [DOWNLOADED] scraped data files/Supervisory_Highlights_Issue_12.pdf
# PDF https://files.consumerfinance.gov/f/documents/Mortgage_Servicing_Supervisory_Highlights_11_Final_web_.pdf
# [DOWNLOADED] scraped data files/Mortgage_Servicing_Supervisory_Highlights_11_Final_web_.pdf
# PDF https://files.consumerfinance.gov/f/201603_cfpb_supervisory-highlights.pdf
# [DOWNLOADED] scraped data files/201603_cfpb_supervisory-highlights.pdf
# PDF https://files.consumerfinance.gov/f/201510_cfpb_supervisory-highlights.pdf
# [DOWNLOADED] scraped data files/201510_cfpb_supervisory-highlights.pdf
# PDF https://files.consumerfinance.gov/f/201506_cfpb_supervisory-highlights.pdf
# [DOWNLOADED] scraped data files/201506_cfpb_supervisory-highlights.pdf
# PDF https://files.consumerfinance.gov/f/201503_cfpb_supervisory-highlights-winter-2015.pdf
# [DOWNLOADED] scraped data files/201503_cfpb_supervisory-highlights-winter-2015.pdf
# PDF https://files.consumerfinance.gov/f/201410_cfpb_supervisory-highlights_fall-2014.pdf
# [DOWNLOADED] scraped data files/201410_cfpb_supervisory-highlights_fall-2014.pdf
# PDF https://files.consumerfinance.gov/f/201409_cfpb_supervisory-highlights_auto-lending_summer-2014.pdf
# [DOWNLOADED] scraped data files/201409_cfpb_supervisory-highlights_auto-lending_summer-2014.pdf
# PDF https://files.consumerfinance.gov/f/201405_cfpb_supervisory-highlights-spring-2014.pdf
# [DOWNLOADED] scraped data files/201405_cfpb_supervisory-highlights-spring-2014.pdf
# PDF https://files.consumerfinance.gov/f/201401_cfpb_supervisory-highlights-winter-2013.pdf
# [DOWNLOADED] scraped data files/201401_cfpb_supervisory-highlights-winter-2013.pdf
# PDF https://files.consumerfinance.gov/f/201308_cfpb_supervisory-highlights_august.pdf
# [DOWNLOADED] scraped data files/201308_cfpb_supervisory-highlights_august.pdf
# PDF https://files.consumerfinance.gov/f/201210_cfpb_supervisory-highlights-fall-2012.pdf
# [DOWNLOADED] scraped data files/201210_cfpb_supervisory-highlights-fall-2012.pdf
# [SKIP] Ignored link: /activity-log/?topics=compliance&topics=supervision
# [INFO] Scraped 38 records

# %%
# Save to parquet with pyarrow
data_summary_dir = 'pdf scrape reports/'
scraped_data_name = data_summary_dir+'scraped_data_'+str(scrape_date)+'.parquet'
df.to_parquet(scraped_data_name, engine='pyarrow', compression='snappy')

# Read it back
df = pd.read_parquet(scraped_data_name, engine='pyarrow')
print(df)
# Out:
#                                                 Title  \
# 0   Advanced Technologies Special Edition, Issue 3...
# 1   Supervisory Highlights: Special Edition Studen...
# 2      Supervisory Highlights, Issue 37 (Winter 2024)
# 3   Supervisory Highlights: Auto Finance Special E...
# 4   Supervisory Highlights: Servicing and Collecti...
# 5       Supervisory Highlights, Issue 32, Spring 2024
# 6       Supervisory Highlights, Issue 33, Spring 2024
# 7   Supervisory Highlights Junk Fees Update Specia...
# 8                  Summer 2023 Supervisory Highlights
# 9    Supervisory Highlights Special Edition Junk Fees
# 10                   Fall 2022 Supervisory Highlights
# 11  Supervisory Highlights Student Loan Servicing ...
# 12                 Spring 2022 Supervisory Highlights
# 13                   Fall 2021 Supervisory Highlights
# 14                 Summer 2021 Supervisory Highlights
# 15  COVID-19 Prioritized Assessments Special Editi...
# 16                 Winter 2020 Supervisory Highlights
# 17                 Summer 2020 Supervisory Highlights
# 18                   Fall 2019 Supervisory Highlights
# 19                 Summer 2019 Supervisory Highlights
# 20                 Winter 2019 Supervisory Highlights
# 21                 Summer 2018 Supervisory Highlights
# 22                 Summer 2017 Supervisory Highlights
# 23                 Spring 2017 Supervisory Highlights
# 24  Supervisory Highlights Consumer Reporting Spec...
# 25                   Fall 2016 Supervisory Highlights
# 26                 Summer 2016 Supervisory Highlights
# 27  Supervisory Highlights Mortgage Servicing Spec...
# 28                 Winter 2016 Supervisory Highlights
# 29                   Fall 2015 Supervisory Highlights
# 30                 Summer 2015 Supervisory Highlights
# 31                 Winter 2015 Supervisory Highlights
# 32                   Fall 2014 Supervisory Highlights
# 33                 Summer 2014 Supervision Highlights
# 34                 Spring 2014 Supervision Highlights
# 35                 Winter 2013 Supervisory Highlights
# 36                 Summer 2013 Supervisory Highlights
# 37                   Fall 2012 Supervisory Highlights
#
#                                                  Link     Link Type  \
# 0   /data-research/research-reports/supervisory-hi...  LANDING_PAGE
# 1   https://files.consumerfinance.gov/f/documents/...           PDF
# 2   https://files.consumerfinance.gov/f/documents/...           PDF
# 3   https://files.consumerfinance.gov/f/documents/...           PDF
# 4   https://files.consumerfinance.gov/f/documents/...           PDF
# 5   https://files.consumerfinance.gov/f/documents/...           PDF
# 6   https://files.consumerfinance.gov/f/documents/...           PDF
# 7   https://files.consumerfinance.gov/f/documents/...           PDF
# 8   https://files.consumerfinance.gov/f/documents/...           PDF
# 9   https://files.consumerfinance.gov/f/documents/...           PDF
# 10  https://files.consumerfinance.gov/f/documents/...           PDF
# 11  https://files.consumerfinance.gov/f/documents/...           PDF
# 12  https://files.consumerfinance.gov/f/documents/...           PDF
# 13  https://files.consumerfinance.gov/f/documents/...           PDF
# 14  https://files.consumerfinance.gov/f/documents/...           PDF
# 15  https://files.consumerfinance.gov/f/documents/...           PDF
# 16  https://files.consumerfinance.gov/f/documents/...           PDF
# 17  https://files.consumerfinance.gov/f/documents/...           PDF
# 18  https://files.consumerfinance.gov/f/documents/...           PDF
# 19  https://files.consumerfinance.gov/f/documents/...           PDF
# 20  https://files.consumerfinance.gov/f/documents/...           PDF
# 21  /documents/6817/bcfp_supervisory-highlights_is...  RELATIVE_PDF
# 22  /documents/5386/201709_cfpb_Supervisory-Highli...  RELATIVE_PDF
# 23  /documents/4608/201704_cfpb_Supervisory-Highli...  RELATIVE_PDF
# 24  /documents/2774/201703_cfpb_Supervisory-Highli...  RELATIVE_PDF
# 25  https://files.consumerfinance.gov/f/documents/...           PDF
# 26  https://files.consumerfinance.gov/f/documents/...           PDF
# 27  https://files.consumerfinance.gov/f/documents/...           PDF
# 28  https://files.consumerfinance.gov/f/201603_cfp...           PDF
# 29  https://files.consumerfinance.gov/f/201510_cfp...           PDF
# 30  https://files.consumerfinance.gov/f/201506_cfp...           PDF
# 31  https://files.consumerfinance.gov/f/201503_cfp...           PDF
# 32  https://files.consumerfinance.gov/f/201410_cfp...           PDF
# 33  https://files.consumerfinance.gov/f/201409_cfp...           PDF
# 34  https://files.consumerfinance.gov/f/201405_cfp...           PDF
# 35  https://files.consumerfinance.gov/f/201401_cfp...           PDF
# 36  https://files.consumerfinance.gov/f/201308_cfp...           PDF
# 37  https://files.consumerfinance.gov/f/201210_cfp...           PDF
#
#                                       Normalized Link     Year   Season  \
# 0   https://www.consumerfinance.gov/data-research/...     2025   Winter
# 1   https://files.consumerfinance.gov/f/documents/...     2024   Winter
# 2   https://files.consumerfinance.gov/f/documents/...     2024   Winter
# 3   https://files.consumerfinance.gov/f/documents/...     2024     Fall
# 4   https://files.consumerfinance.gov/f/documents/...     2024   Summer
# 5   https://files.consumerfinance.gov/f/documents/...     2024   Spring
# 6   https://files.consumerfinance.gov/f/documents/...     2024   Spring
# 7   https://files.consumerfinance.gov/f/documents/...     2023     Fall
# 8   https://files.consumerfinance.gov/f/documents/...     2023   Summer
# 9   https://files.consumerfinance.gov/f/documents/...  Unknown  Unknown
# 10  https://files.consumerfinance.gov/f/documents/...     2022     Fall
# 11  https://files.consumerfinance.gov/f/documents/...  Unknown  Unknown
# 12  https://files.consumerfinance.gov/f/documents/...     2022   Spring
# 13  https://files.consumerfinance.gov/f/documents/...     2021     Fall
# 14  https://files.consumerfinance.gov/f/documents/...     2021   Summer
# 15  https://files.consumerfinance.gov/f/documents/...  Unknown  Unknown
# 16  https://files.consumerfinance.gov/f/documents/...     2020   Winter
# 17  https://files.consumerfinance.gov/f/documents/...     2020   Summer
# 18  https://files.consumerfinance.gov/f/documents/...     2019     Fall
# 19  https://files.consumerfinance.gov/f/documents/...     2019   Summer
# 20  https://files.consumerfinance.gov/f/documents/...     2019   Winter
# 21  https://www.consumerfinance.gov/documents/6817...     2018   Summer
# 22  https://www.consumerfinance.gov/documents/5386...     2017   Summer
# 23  https://www.consumerfinance.gov/documents/4608...     2017   Spring
# 24  https://www.consumerfinance.gov/documents/2774...  Unknown  Unknown
# 25  https://files.consumerfinance.gov/f/documents/...     2016     Fall
# 26  https://files.consumerfinance.gov/f/documents/...     2016   Summer
# 27  https://files.consumerfinance.gov/f/documents/...  Unknown  Unknown
# 28  https://files.consumerfinance.gov/f/201603_cfp...     2016   Winter
# 29  https://files.consumerfinance.gov/f/201510_cfp...     2015     Fall
# 30  https://files.consumerfinance.gov/f/201506_cfp...     2015   Summer
# 31  https://files.consumerfinance.gov/f/201503_cfp...     2015   Winter
# 32  https://files.consumerfinance.gov/f/201410_cfp...     2014     Fall
# 33  https://files.consumerfinance.gov/f/201409_cfp...     2014   Summer
# 34  https://files.consumerfinance.gov/f/201405_cfp...     2014   Spring
# 35  https://files.consumerfinance.gov/f/201401_cfp...     2013   Winter
# 36  https://files.consumerfinance.gov/f/201308_cfp...     2013   Summer
# 37  https://files.consumerfinance.gov/f/201210_cfp...     2012     Fall
#
#    Agency                                      File Location Drive Link  \
# 0    CFPB  scraped data files/cfpb_supervisory-highlights...
# 1    CFPB  scraped data files/cfpb_supervisory-highlights...
# 2    CFPB  scraped data files/cfpb_Supervisory-Highlights...
# 3    CFPB  scraped data files/cfpb_supervisory-highlights...
# 4    CFPB  scraped data files/cfpb_supervisory-highlights...
# 5    CFPB  scraped data files/cfpb_supervisory-highlights...
# 6    CFPB  scraped data files/cfpb_supervisory-highlights...
# 7    CFPB  scraped data files/cfpb_supervisory_highlights...
# 8    CFPB  scraped data files/cfpb_supervisory-highlights...
# 9    CFPB  scraped data files/cfpb_supervisory-highlights...
# 10   CFPB  scraped data files/cfpb_supervisory-highlights...
# 11   CFPB  scraped data files/cfpb_student-loan-servicing...
# 12   CFPB  scraped data files/cfpb_supervisory-highlights...
# 13   CFPB  scraped data files/cfpb_supervisory-highlights...
# 14   CFPB  scraped data files/cfpb_supervisory-highlights...
# 15   CFPB  scraped data files/cfpb_supervisory-highlights...
# 16   CFPB  scraped data files/cfpb_supervisory-highlights...
# 17   CFPB  scraped data files/cfpb_supervisory-highlights...
# 18   CFPB  scraped data files/cfpb_supervisory-highlights...
# 19   CFPB  scraped data files/cfpb_supervisory-highlights...
# 20   CFPB  scraped data files/cfpb_supervisory-highlights...
# 21   CFPB  scraped data files/bcfp_supervisory-highlights...
# 22   CFPB  scraped data files/201709_cfpb_Supervisory-Hig...
# 23   CFPB  scraped data files/201704_cfpb_Supervisory-Hig...
# 24   CFPB  scraped data files/201703_cfpb_Supervisory-Hig...
# 25   CFPB  scraped data files/Supervisory_Highlights_Issu...
# 26   CFPB  scraped data files/Supervisory_Highlights_Issu...
# 27   CFPB  scraped data files/Mortgage_Servicing_Supervis...
# 28   CFPB  scraped data files/201603_cfpb_supervisory-hig...
# 29   CFPB  scraped data files/201510_cfpb_supervisory-hig...
# 30   CFPB  scraped data files/201506_cfpb_supervisory-hig...
# 31   CFPB  scraped data files/201503_cfpb_supervisory-hig...
# 32   CFPB  scraped data files/201410_cfpb_supervisory-hig...
# 33   CFPB  scraped data files/201409_cfpb_supervisory-hig...
# 34   CFPB  scraped data files/201405_cfpb_supervisory-hig...
# 35   CFPB  scraped data files/201401_cfpb_supervisory-hig...
# 36   CFPB  scraped data files/201308_cfpb_supervisory-hig...
# 37   CFPB  scraped data files/201210_cfpb_supervisory-hig...
#
#     Summarized? Summary Scraped Date
# 0         False             20250313
# 1         False             20250313
# 2         False             20250313
# 3         False             20250313
# 4         False             20250313
# 5         False             20250313
# 6         False             20250313
# 7         False             20250313
# 8         False             20250313
# 9         False             20250313
# 10        False             20250313
# 11        False             20250313
# 12        False             20250313
# 13        False             20250313
# 14        False             20250313
# 15        False             20250313
# 16        False             20250313
# 17        False             20250313
# 18        False             20250313
# 19        False             20250313
# 20        False             20250313
# 21        False             20250313
# 22        False             20250313
# 23        False             20250313
# 24        False             20250313
# 25        False             20250313
# 26        False             20250313
# 27        False             20250313
# 28        False             20250313
# 29        False             20250313
# 30        False             20250313
# 31        False             20250313
# 32        False             20250313
# 33        False             20250313
# 34        False             20250313
# 35        False             20250313
# 36        False             20250313
# 37        False             20250313
